# %% [markdown]
# ___
# # Analyze Inferred-GRN Robustness
# ___
# - Simulate random node failures and hub-targeted removals
# - Batch-process phase-specific network directories
# - Outputs: robustness plots per network and an aggregate AUC summary
#
# We evaluate directed GRNs across `data/inferred_grn/phase1` through `phase4`, comparing random node failures to degree-based targeted attacks while tracking the giant connected component (GCC) fraction.
# - Edge-list format is detected automatically (tab, comma, semicolon, pipe, or whitespace).
# - GCC is measured on the **weakly connected** component by default (configurable).

# %%
# import modules
from __future__ import annotations

import random
from pathlib import Path
from typing import Iterable, List, Dict, Tuple, Optional

import numpy as np
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

# %%
## infers the delimiter used in an edge list file
def guess_delimiter(path: str | Path, sample_lines: int = 20) -> Optional[str]:
    candidates = ["	", ",", ";", "|"]
    with open(path, "r", encoding="utf-8", errors="ignore") as handle:
        for _ in range(sample_lines):
            line = handle.readline()
            if not line:
                break
            line = line.strip()
            if not line or line.startswith("#"):
                continue
            for delim in candidates:
                if delim in line:
                    return delim
    return None

# loads an edge list into a NetworkX graph
def load_graph_from_edgelist(
    path: str | Path,
    *,
    directed: bool = True,
    weighted: bool = False,
) -> nx.Graph:
    path = Path(path)
    delim = guess_delimiter(path)
    create_using = nx.DiGraph() if directed else nx.Graph()
    read_kwargs = {
        "create_using": create_using,
        "nodetype": str,
        "comments": "#",
    }
    if delim is not None:
        read_kwargs["delimiter"] = delim
    if weighted:
        read_kwargs["data"] = [("weight", float)]
    else:
        read_kwargs["data"] = False
    G = nx.read_edgelist(path, **read_kwargs)
    G.remove_edges_from(nx.selfloop_edges(G))
    if G.number_of_nodes() == 0:
        raise ValueError(f"No nodes loaded from {path}. Check delimiter/format.")
    return G

# iterates graph components according to the selected mode
def iter_components(G: nx.Graph, component_mode: str = "weak"):
    if component_mode == "strong":
        if not G.is_directed():
            raise ValueError("strong mode only support directed graph")
        yield from nx.strongly_connected_components(G)
    elif component_mode == "weak":
        if G.is_directed():
            yield from nx.weakly_connected_components(G)
        else:
            yield from nx.connected_components(G)
    elif component_mode == "undirected":
        if G.is_directed():
            yield from nx.connected_components(G.to_undirected())
        else:
            yield from nx.connected_components(G)
    else:
        raise ValueError(f"Unknown component_mode: {component_mode}")

# The function extract_reference_component extracts the largest component
def extract_reference_component(G: nx.Graph, component_mode: str = "weak") -> nx.Graph:
    # select the largest component in component mode
    if G.number_of_nodes() == 0:
        return G
    comps = list(iter_components(G, component_mode=component_mode))
    if len(comps) <= 1:
        return G
    largest = max(comps, key=len)
    return G.subgraph(largest).copy()

# computes the GCC fraction of the graph
def gcc_fraction(G: nx.Graph, component_mode: str = "weak") -> float:
    if G.number_of_nodes() == 0:
        return 0.0
    largest = max((len(c) for c in iter_components(G, component_mode=component_mode)), default=0)
    return largest / max(1, G.number_of_nodes())

# %%
# creates the degree-based attack order
def targeted_attack_order_degree(G: nx.Graph, mode: str = "total") -> List[str]:
    if mode not in {"total", "in", "out"}:
        raise ValueError("chose 'total' or 'in' or 'out'")
    if mode in {"in", "out"} and not G.is_directed():
        raise ValueError("undirtected graph can't use in/out mode")

    H = G.copy()
    order: List[str] = []
    while H.number_of_nodes() > 0:
        if mode == "total":
            deg_pairs = list(H.degree())
        elif mode == "in":
            deg_pairs = list(H.in_degree())
        else:  # mode == "out"
            deg_pairs = list(H.out_degree())
        max_deg = max((d for _, d in deg_pairs), default=0)
        candidates = [n for n, d in deg_pairs if d == max_deg]
        node = sorted(candidates)[0]
        order.append(node)
        H.remove_node(node)
    return order

# generates multiple random removal orders
def random_failure_orders(G: nx.Graph, n_trials: int, seed: int = 42) -> List[List[str]]:
    rng = random.Random(seed)
    nodes = list(G.nodes())
    return [rng.sample(nodes, len(nodes)) for _ in range(n_trials)]

# simulates GCC curves during node removal
def simulate_removal_curve(
    G: nx.Graph,
    removal_order: List[str],
    *,
    component_mode: str = "weak",
) -> Dict[str, np.ndarray]:
    H = G.copy()
    N = H.number_of_nodes()
    removed_frac = np.zeros(N + 1)
    gcc_frac = np.zeros(N + 1)
    removed_frac[0] = 0.0
    gcc_frac[0] = gcc_fraction(H, component_mode=component_mode)

    for i, node in enumerate(removal_order, start=1):
        if H.has_node(node):
            H.remove_node(node)
        removed_frac[i] = i / N
        gcc_frac[i] = gcc_fraction(H, component_mode=component_mode)
    return {"removed_frac": removed_frac, "gcc_frac": gcc_frac}

# summarizes random failure curves
def aggregate_random_failures(
    G: nx.Graph,
    *,
    n_trials: int = 20,
    seed: int = 42,
    component_mode: str = "weak",
) -> Dict[str, np.ndarray]:
    orders = random_failure_orders(G, n_trials=n_trials, seed=seed)
    curves = [simulate_removal_curve(G, o, component_mode=component_mode)["gcc_frac"] for o in orders]
    arr = np.vstack(curves)
    mean_curve = arr.mean(axis=0)
    std_curve = arr.std(axis=0)
    removed_frac = simulate_removal_curve(G, orders[0], component_mode=component_mode)["removed_frac"]
    return {
        "removed_frac": removed_frac,
        "mean_gcc": mean_curve,
        "std_gcc": std_curve,
    }

# plots and saves the robustness curves
def plot_robustness(
    name: str,
    phase: str,
    removed_frac: np.ndarray,
    random_mean: np.ndarray,
    random_std: np.ndarray,
    targeted_curve: np.ndarray,
    *,
    component_mode: str,
    target_mode: str,
    base_dir: str | Path = "./",
    show: bool = True,
) -> Path:
    base_dir = Path(base_dir)
    fig_dir = base_dir / phase
    fig_dir.mkdir(parents=True, exist_ok=True)
    fig, ax = plt.subplots(figsize=(6.0, 4.5))
    ax.plot(removed_frac, random_mean, label="Random failure (mean)")
    ax.fill_between(removed_frac, random_mean - random_std, random_mean + random_std, alpha=0.2, label="Random ±1σ")
    ax.plot(removed_frac, targeted_curve, label=f"Targeted attack ({target_mode})")
    ax.set_xlabel("Removed fraction of nodes")
    ax.set_ylabel("GCC fraction (|C_max| / N)")
    ax.set_title(f"Robustness: {phase} / {name}")
    ax.legend()
    ax.grid(True, linestyle="--", alpha=0.4)
    fig_path = fig_dir / f"{name}.png"
    fig.tight_layout()
    fig.savefig(fig_path, dpi=200)
    if show:
        plt.show()
    else:
        plt.close(fig)
    return fig_path

# %%
# infers the phase name from the file path
def infer_phase(path: Path, default: str = "unknown") -> str:
    for parent in path.parents:
        name = parent.name
        if name.lower().startswith("phase"):
            return name
    return default

# evaluates robustness for a single network
def analyze_one_file(
    path: str | Path,
    *,
    name: Optional[str] = None,
    directed: bool = True,
    weighted: bool = False,
    component_mode: str = "weak",
    target_mode: str = "total",
    n_random_trials: int = 20,
    seed: int = 42,
    fig_base: str | Path = "./",
    show_plot: bool = True,
) -> Dict[str, object]:
    path = Path(path)
    if name is None:
        name = path.stem

    phase = infer_phase(path)

    print(f"[INFO] Loading: {path}")
    G = load_graph_from_edgelist(path, directed=directed, weighted=weighted)
    raw_nodes, raw_edges = G.number_of_nodes(), G.number_of_edges()

    G_ref = extract_reference_component(G, component_mode=component_mode)
    ref_nodes, ref_edges = G_ref.number_of_nodes(), G_ref.number_of_edges()
    if ref_nodes != raw_nodes:
        print(f"[INFO] Using largest {component_mode} component: {ref_nodes}/{raw_nodes} nodes")

    rand_stats = aggregate_random_failures(
        G_ref,
        n_trials=n_random_trials,
        seed=seed,
        component_mode=component_mode,
    )
    order_tgt = targeted_attack_order_degree(G_ref, mode=target_mode)
    tgt_curve = simulate_removal_curve(G_ref, order_tgt, component_mode=component_mode)["gcc_frac"]

    random_auc = float(np.trapz(rand_stats["mean_gcc"], rand_stats["removed_frac"]))
    targeted_auc = float(np.trapz(tgt_curve, rand_stats["removed_frac"]))
    print(f"[INFO] Random AUC   : {random_auc:.6f}")
    print(f"[INFO] Targeted AUC : {targeted_auc:.6f}")

    fig_path = plot_robustness(
        name,
        phase,
        rand_stats["removed_frac"],
        rand_stats["mean_gcc"],
        rand_stats["std_gcc"],
        tgt_curve,
        component_mode=component_mode,
        target_mode=target_mode,
        base_dir=fig_base,
        show=show_plot,
    )

    print(f"[OK] Saved figure: {fig_path}")

    return {
        "phase": phase,
        "network": name,
        "source_path": str(path),
        "raw_nodes": raw_nodes,
        "raw_edges": raw_edges,
        "ref_nodes": ref_nodes,
        "ref_edges": ref_edges,
        "component_mode": component_mode,
        "target_mode": target_mode,
        "n_random_trials": n_random_trials,
        "seed": seed,
        "initial_gcc": rand_stats["mean_gcc"][0],
        "random_auc": random_auc,
        "targeted_auc": targeted_auc,
        "figure_path": str(fig_path),
    }

# %%
# runs robustness analysis over multiple networks
def analyze_directory(
    base_dirs: Iterable[str | Path],
    *,
    patterns: str = "*.ncol,*.txt,*.tsv,*.csv",
    directed: bool = True,
    weighted: bool = False,
    component_mode: str = "weak",
    target_mode: str = "total",
    n_random_trials: int = 20,
    seed: int = 42,
    fig_base: str | Path = "./",
    summary_dir: str | Path = "./",
) -> pd.DataFrame:
    if isinstance(base_dirs, (str, Path)):
        base_dirs = [base_dirs]

    all_paths: List[Path] = []
    for base in base_dirs:
        base = Path(base)
        for pattern in patterns.split(","):
            pattern = pattern.strip()
            if not pattern:
                continue
            all_paths.extend(base.glob(f"**/{pattern}"))

    unique_paths = sorted({p.resolve() for p in all_paths})
    if not unique_paths:
        print(f"[WARN] No files matched in {base_dirs} with patterns '{patterns}'")
        return pd.DataFrame(columns=["phase", "network", "random_auc", "targeted_auc"])

    records: List[Dict[str, object]] = []
    total = len(unique_paths)
    for idx, path in enumerate(unique_paths, start=1):
        if idx > 1:
            print()
        print(f"[BATCH {idx}/{total}] {path}")
        try:
            result = analyze_one_file(
                path,
                name=path.stem,
                directed=directed,
                weighted=weighted,
                component_mode=component_mode,
                target_mode=target_mode,
                n_random_trials=n_random_trials,
                seed=seed,
                fig_base=fig_base,
                show_plot=False,
            )
            records.append(result)
        except Exception as exc:
            print(f"[ERROR] {path}: {exc}")
            records.append({
                "phase": infer_phase(path),
                "network": path.stem,
                "source_path": str(path),
                "error": str(exc),
            })

    full_df = pd.DataFrame(records)

    summary_df = full_df.copy()
    if "error" in summary_df.columns:
        summary_df = summary_df[summary_df["error"].isna()]
    summary_df = summary_df.dropna(subset=["random_auc", "targeted_auc"], how="any")
    summary_df = summary_df.loc[:, ["phase", "network", "random_auc", "targeted_auc"]]

    summary_dir = Path(summary_dir)
    summary_dir.mkdir(parents=True, exist_ok=True)
    summary_path = summary_dir / "robustness_summary.csv"
    summary_df.to_csv(summary_path, index=False)
    print(f"[OK] Saved summary table: {summary_path}")

    return summary_df.reset_index(drop=True)

# %%
root_dir = Path("../../data/inferred_grn")
phase_dirs = [root_dir / f"phase{i}" for i in range(1, 5)]

Robustness_results = analyze_directory(
    phase_dirs,
    patterns="*.ncol",
    directed=True,
    weighted=False,
    component_mode="weak",
    target_mode="total",
    n_random_trials=20,
    seed=42,
    fig_base="../../data/result/robustness/figure",
    summary_dir="../../data/result/robustness",
)
# Out:
# [BATCH 1/40] /home/Data_Drive_8TB_2/Controllability/single-cell-grn-control/data/inferred_grn/phase1/Blastomeres.ncol
# [INFO] Loading: /home/Data_Drive_8TB_2/Controllability/single-cell-grn-control/data/inferred_grn/phase1/Blastomeres.ncol
# /tmp/ipykernel_1672719/1604728258.py:47: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   random_auc = float(np.trapz(rand_stats["mean_gcc"], rand_stats["removed_frac"]))
# /tmp/ipykernel_1672719/1604728258.py:48: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   targeted_auc = float(np.trapz(tgt_curve, rand_stats["removed_frac"]))
# [INFO] Random AUC   : 0.589191
# [INFO] Targeted AUC : 0.032857
# [OK] Saved figure: ../../data/result/robustness/figure/phase1/Blastomeres.png
#
# [BATCH 2/40] /home/Data_Drive_8TB_2/Controllability/single-cell-grn-control/data/inferred_grn/phase1/Enveloping_Layer.ncol
# [INFO] Loading: /home/Data_Drive_8TB_2/Controllability/single-cell-grn-control/data/inferred_grn/phase1/Enveloping_Layer.ncol
# [INFO] Random AUC   : 0.744938
# [INFO] Targeted AUC : 0.062697
# [OK] Saved figure: ../../data/result/robustness/figure/phase1/Enveloping_Layer.png
#
# [BATCH 3/40] /home/Data_Drive_8TB_2/Controllability/single-cell-grn-control/data/inferred_grn/phase1/Primordial_Germ_cells.ncol
# [INFO] Loading: /home/Data_Drive_8TB_2/Controllability/single-cell-grn-control/data/inferred_grn/phase1/Primordial_Germ_cells.ncol
# [INFO] Using largest weak component: 257/259 nodes
# [INFO] Random AUC   : 0.747251
# [INFO] Targeted AUC : 0.091122
# [OK] Saved figure: ../../data/result/robustness/figure/phase1/Primordial_Germ_cells.png
#
# [BATCH 4/40] /home/Data_Drive_8TB_2/Controllability/single-cell-grn-control/data/inferred_grn/phase2/Ectoderm.ncol
# [INFO] Loading: /home/Data_Drive_8TB_2/Controllability/single-cell-grn-control/data/inferred_grn/phase2/Ectoderm.ncol
# [INFO] Random AUC   : 0.632711
# [INFO] Targeted AUC : 0.036512
# [OK] Saved figure: ../../data/result/robustness/figure/phase2/Ectoderm.png
#
# [BATCH 5/40] /home/Data_Drive_8TB_2/Controllability/single-cell-grn-control/data/inferred_grn/phase2/Enveloping_Layer.ncol
# [INFO] Loading: /home/Data_Drive_8TB_2/Controllability/single-cell-grn-control/data/inferred_grn/phase2/Enveloping_Layer.ncol
# [INFO] Random AUC   : 0.665720
# [INFO] Targeted AUC : 0.041767
# [OK] Saved figure: ../../data/result/robustness/figure/phase2/Enveloping_Layer.png
#
# [BATCH 6/40] /home/Data_Drive_8TB_2/Controllability/single-cell-grn-control/data/inferred_grn/phase2/Other_Axial_Mesoderm.ncol
# [INFO] Loading: /home/Data_Drive_8TB_2/Controllability/single-cell-grn-control/data/inferred_grn/phase2/Other_Axial_Mesoderm.ncol
# [INFO] Random AUC   : 0.652983
# [INFO] Targeted AUC : 0.036349
# [OK] Saved figure: ../../data/result/robustness/figure/phase2/Other_Axial_Mesoderm.png
#
# [BATCH 7/40] /home/Data_Drive_8TB_2/Controllability/single-cell-grn-control/data/inferred_grn/phase2/Other_Mesendoderm.ncol
# [INFO] Loading: /home/Data_Drive_8TB_2/Controllability/single-cell-grn-control/data/inferred_grn/phase2/Other_Mesendoderm.ncol
# [INFO] Random AUC   : 0.615644
# [INFO] Targeted AUC : 0.028812
# [OK] Saved figure: ../../data/result/robustness/figure/phase2/Other_Mesendoderm.png
#
# [BATCH 8/40] /home/Data_Drive_8TB_2/Controllability/single-cell-grn-control/data/inferred_grn/phase2/Primordial_Germ_cells.ncol
# [INFO] Loading: /home/Data_Drive_8TB_2/Controllability/single-cell-grn-control/data/inferred_grn/phase2/Primordial_Germ_cells.ncol
# [INFO] Random AUC   : 0.629895
# [INFO] Targeted AUC : 0.044960
# [OK] Saved figure: ../../data/result/robustness/figure/phase2/Primordial_Germ_cells.png
#
# [BATCH 9/40] /home/Data_Drive_8TB_2/Controllability/single-cell-grn-control/data/inferred_grn/phase3/Ectoderm.ncol
# [INFO] Loading: /home/Data_Drive_8TB_2/Controllability/single-cell-grn-control/data/inferred_grn/phase3/Ectoderm.ncol
# [INFO] Random AUC   : 0.633301
# [INFO] Targeted AUC : 0.037008
# [OK] Saved figure: ../../data/result/robustness/figure/phase3/Ectoderm.png
#
# [BATCH 10/40] /home/Data_Drive_8TB_2/Controllability/single-cell-grn-control/data/inferred_grn/phase3/Enveloping_Layer.ncol
# [INFO] Loading: /home/Data_Drive_8TB_2/Controllability/single-cell-grn-control/data/inferred_grn/phase3/Enveloping_Layer.ncol
# [INFO] Random AUC   : 0.605942
# [INFO] Targeted AUC : 0.031439
# [OK] Saved figure: ../../data/result/robustness/figure/phase3/Enveloping_Layer.png
#
# [BATCH 11/40] /home/Data_Drive_8TB_2/Controllability/single-cell-grn-control/data/inferred_grn/phase3/Notochord.ncol
# [INFO] Loading: /home/Data_Drive_8TB_2/Controllability/single-cell-grn-control/data/inferred_grn/phase3/Notochord.ncol
# [INFO] Random AUC   : 0.606263
# [INFO] Targeted AUC : 0.031548
# [OK] Saved figure: ../../data/result/robustness/figure/phase3/Notochord.png
#
# [BATCH 12/40] /home/Data_Drive_8TB_2/Controllability/single-cell-grn-control/data/inferred_grn/phase3/Other_Mesendoderm.ncol
# [INFO] Loading: /home/Data_Drive_8TB_2/Controllability/single-cell-grn-control/data/inferred_grn/phase3/Other_Mesendoderm.ncol
# [INFO] Random AUC   : 0.641630
# [INFO] Targeted AUC : 0.024084
# [OK] Saved figure: ../../data/result/robustness/figure/phase3/Other_Mesendoderm.png
#
# [BATCH 13/40] /home/Data_Drive_8TB_2/Controllability/single-cell-grn-control/data/inferred_grn/phase3/Paraxial_Mesoderm.ncol
# [INFO] Loading: /home/Data_Drive_8TB_2/Controllability/single-cell-grn-control/data/inferred_grn/phase3/Paraxial_Mesoderm.ncol
# [INFO] Random AUC   : 0.592667
# [INFO] Targeted AUC : 0.024743
# [OK] Saved figure: ../../data/result/robustness/figure/phase3/Paraxial_Mesoderm.png
#
# [BATCH 14/40] /home/Data_Drive_8TB_2/Controllability/single-cell-grn-control/data/inferred_grn/phase3/Prechordal_Plate.ncol
# [INFO] Loading: /home/Data_Drive_8TB_2/Controllability/single-cell-grn-control/data/inferred_grn/phase3/Prechordal_Plate.ncol
# [INFO] Random AUC   : 0.513162
# [INFO] Targeted AUC : 0.025804
# [OK] Saved figure: ../../data/result/robustness/figure/phase3/Prechordal_Plate.png
#
# [BATCH 15/40] /home/Data_Drive_8TB_2/Controllability/single-cell-grn-control/data/inferred_grn/phase3/Primordial_Germ_cells.ncol
# [INFO] Loading: /home/Data_Drive_8TB_2/Controllability/single-cell-grn-control/data/inferred_grn/phase3/Primordial_Germ_cells.ncol
# [INFO] Random AUC   : 0.671608
# [INFO] Targeted AUC : 0.076499
# [OK] Saved figure: ../../data/result/robustness/figure/phase3/Primordial_Germ_cells.png
#
# [BATCH 16/40] /home/Data_Drive_8TB_2/Controllability/single-cell-grn-control/data/inferred_grn/phase4/Adaxial_Cells.ncol
# [INFO] Loading: /home/Data_Drive_8TB_2/Controllability/single-cell-grn-control/data/inferred_grn/phase4/Adaxial_Cells.ncol
# [INFO] Random AUC   : 0.621350
# [INFO] Targeted AUC : 0.031813
# [OK] Saved figure: ../../data/result/robustness/figure/phase4/Adaxial_Cells.png
#
# [BATCH 17/40] /home/Data_Drive_8TB_2/Controllability/single-cell-grn-control/data/inferred_grn/phase4/Cephalic_Mesoderm.ncol
# [INFO] Loading: /home/Data_Drive_8TB_2/Controllability/single-cell-grn-control/data/inferred_grn/phase4/Cephalic_Mesoderm.ncol
# [INFO] Random AUC   : 0.739528
# [INFO] Targeted AUC : 0.136683
# [OK] Saved figure: ../../data/result/robustness/figure/phase4/Cephalic_Mesoderm.png
#
# [BATCH 18/40] /home/Data_Drive_8TB_2/Controllability/single-cell-grn-control/data/inferred_grn/phase4/Diencephalon.ncol
# [INFO] Loading: /home/Data_Drive_8TB_2/Controllability/single-cell-grn-control/data/inferred_grn/phase4/Diencephalon.ncol
# [INFO] Random AUC   : 0.634132
# [INFO] Targeted AUC : 0.044032
# [OK] Saved figure: ../../data/result/robustness/figure/phase4/Diencephalon.png
#
# [BATCH 19/40] /home/Data_Drive_8TB_2/Controllability/single-cell-grn-control/data/inferred_grn/phase4/Endoderm_Pancreatic+Intestinal.ncol
# [INFO] Loading: /home/Data_Drive_8TB_2/Controllability/single-cell-grn-control/data/inferred_grn/phase4/Endoderm_Pancreatic+Intestinal.ncol
# [INFO] Random AUC   : 0.667592
# [INFO] Targeted AUC : 0.055440
# [OK] Saved figure: ../../data/result/robustness/figure/phase4/Endoderm_Pancreatic+Intestinal.png
#
# [BATCH 20/40] /home/Data_Drive_8TB_2/Controllability/single-cell-grn-control/data/inferred_grn/phase4/Endoderm_Pharyngeal.ncol
# [INFO] Loading: /home/Data_Drive_8TB_2/Controllability/single-cell-grn-control/data/inferred_grn/phase4/Endoderm_Pharyngeal.ncol
# [INFO] Random AUC   : 0.708061
# [INFO] Targeted AUC : 0.091964
# [OK] Saved figure: ../../data/result/robustness/figure/phase4/Endoderm_Pharyngeal.png
#
# [BATCH 21/40] /home/Data_Drive_8TB_2/Controllability/single-cell-grn-control/data/inferred_grn/phase4/Enveloping_Layer.ncol
# [INFO] Loading: /home/Data_Drive_8TB_2/Controllability/single-cell-grn-control/data/inferred_grn/phase4/Enveloping_Layer.ncol
# [INFO] Random AUC   : 0.741106
# [INFO] Targeted AUC : 0.064966
# [OK] Saved figure: ../../data/result/robustness/figure/phase4/Enveloping_Layer.png
#
# [BATCH 22/40] /home/Data_Drive_8TB_2/Controllability/single-cell-grn-control/data/inferred_grn/phase4/Epidermis.ncol
# [INFO] Loading: /home/Data_Drive_8TB_2/Controllability/single-cell-grn-control/data/inferred_grn/phase4/Epidermis.ncol
# [INFO] Random AUC   : 0.610070
# [INFO] Targeted AUC : 0.037409
# [OK] Saved figure: ../../data/result/robustness/figure/phase4/Epidermis.png
#
# [BATCH 23/40] /home/Data_Drive_8TB_2/Controllability/single-cell-grn-control/data/inferred_grn/phase4/Heart_Primordium.ncol
# [INFO] Loading: /home/Data_Drive_8TB_2/Controllability/single-cell-grn-control/data/inferred_grn/phase4/Heart_Primordium.ncol
# [INFO] Random AUC   : 0.698986
# [INFO] Targeted AUC : 0.111525
# [OK] Saved figure: ../../data/result/robustness/figure/phase4/Heart_Primordium.png
#
# [BATCH 24/40] /home/Data_Drive_8TB_2/Controllability/single-cell-grn-control/data/inferred_grn/phase4/Hematopoietic_ICM.ncol
# [INFO] Loading: /home/Data_Drive_8TB_2/Controllability/single-cell-grn-control/data/inferred_grn/phase4/Hematopoietic_ICM.ncol
# [INFO] Random AUC   : 0.681001
# [INFO] Targeted AUC : 0.067575
# [OK] Saved figure: ../../data/result/robustness/figure/phase4/Hematopoietic_ICM.png
#
# [BATCH 25/40] /home/Data_Drive_8TB_2/Controllability/single-cell-grn-control/data/inferred_grn/phase4/Hematopoietic_RBI+Pronephros.ncol
# [INFO] Loading: /home/Data_Drive_8TB_2/Controllability/single-cell-grn-control/data/inferred_grn/phase4/Hematopoietic_RBI+Pronephros.ncol
# [INFO] Random AUC   : 0.697761
# [INFO] Targeted AUC : 0.113896
# [OK] Saved figure: ../../data/result/robustness/figure/phase4/Hematopoietic_RBI+Pronephros.png
#
# [BATCH 26/40] /home/Data_Drive_8TB_2/Controllability/single-cell-grn-control/data/inferred_grn/phase4/Hindbrain_R3.ncol
# [INFO] Loading: /home/Data_Drive_8TB_2/Controllability/single-cell-grn-control/data/inferred_grn/phase4/Hindbrain_R3.ncol
# [INFO] Random AUC   : 0.721452
# [INFO] Targeted AUC : 0.117428
# [OK] Saved figure: ../../data/result/robustness/figure/phase4/Hindbrain_R3.png
#
# [BATCH 27/40] /home/Data_Drive_8TB_2/Controllability/single-cell-grn-control/data/inferred_grn/phase4/Hindbrain_R4+5+6.ncol
# [INFO] Loading: /home/Data_Drive_8TB_2/Controllability/single-cell-grn-control/data/inferred_grn/phase4/Hindbrain_R4+5+6.ncol
# [INFO] Random AUC   : 0.637969
# [INFO] Targeted AUC : 0.052730
# [OK] Saved figure: ../../data/result/robustness/figure/phase4/Hindbrain_R4+5+6.png
#
# [BATCH 28/40] /home/Data_Drive_8TB_2/Controllability/single-cell-grn-control/data/inferred_grn/phase4/Neural_Plate_Border.ncol
# [INFO] Loading: /home/Data_Drive_8TB_2/Controllability/single-cell-grn-control/data/inferred_grn/phase4/Neural_Plate_Border.ncol
# [INFO] Random AUC   : 0.670825
# [INFO] Targeted AUC : 0.073093
# [OK] Saved figure: ../../data/result/robustness/figure/phase4/Neural_Plate_Border.png
#
# [BATCH 29/40] /home/Data_Drive_8TB_2/Controllability/single-cell-grn-control/data/inferred_grn/phase4/Notochord.ncol
# [INFO] Loading: /home/Data_Drive_8TB_2/Controllability/single-cell-grn-control/data/inferred_grn/phase4/Notochord.ncol
# [INFO] Random AUC   : 0.703408
# [INFO] Targeted AUC : 0.082776
# [OK] Saved figure: ../../data/result/robustness/figure/phase4/Notochord.png
#
# [BATCH 30/40] /home/Data_Drive_8TB_2/Controllability/single-cell-grn-control/data/inferred_grn/phase4/Optic_Cup.ncol
# [INFO] Loading: /home/Data_Drive_8TB_2/Controllability/single-cell-grn-control/data/inferred_grn/phase4/Optic_Cup.ncol
# [INFO] Random AUC   : 0.688320
# [INFO] Targeted AUC : 0.061466
# [OK] Saved figure: ../../data/result/robustness/figure/phase4/Optic_Cup.png
#
# [BATCH 31/40] /home/Data_Drive_8TB_2/Controllability/single-cell-grn-control/data/inferred_grn/phase4/Placode_Adeno+Lens+Trigeminal.ncol
# [INFO] Loading: /home/Data_Drive_8TB_2/Controllability/single-cell-grn-control/data/inferred_grn/phase4/Placode_Adeno+Lens+Trigeminal.ncol
# [INFO] Random AUC   : 0.719162
# [INFO] Targeted AUC : 0.110094
# [OK] Saved figure: ../../data/result/robustness/figure/phase4/Placode_Adeno+Lens+Trigeminal.png
#
# [BATCH 32/40] /home/Data_Drive_8TB_2/Controllability/single-cell-grn-control/data/inferred_grn/phase4/Placode_Epibranchial+Otic.ncol
# [INFO] Loading: /home/Data_Drive_8TB_2/Controllability/single-cell-grn-control/data/inferred_grn/phase4/Placode_Epibranchial+Otic.ncol
# [INFO] Random AUC   : 0.660523
# [INFO] Targeted AUC : 0.059167
# [OK] Saved figure: ../../data/result/robustness/figure/phase4/Placode_Epibranchial+Otic.png
#
# [BATCH 33/40] /home/Data_Drive_8TB_2/Controllability/single-cell-grn-control/data/inferred_grn/phase4/Placode_Olfactory.ncol
# [INFO] Loading: /home/Data_Drive_8TB_2/Controllability/single-cell-grn-control/data/inferred_grn/phase4/Placode_Olfactory.ncol
# [INFO] Random AUC   : 0.708403
# [INFO] Targeted AUC : 0.123403
# [OK] Saved figure: ../../data/result/robustness/figure/phase4/Placode_Olfactory.png
#
# [BATCH 34/40] /home/Data_Drive_8TB_2/Controllability/single-cell-grn-control/data/inferred_grn/phase4/Prechordal_Plate.ncol
# [INFO] Loading: /home/Data_Drive_8TB_2/Controllability/single-cell-grn-control/data/inferred_grn/phase4/Prechordal_Plate.ncol
# [INFO] Random AUC   : 0.543448
# [INFO] Targeted AUC : 0.033921
# [OK] Saved figure: ../../data/result/robustness/figure/phase4/Prechordal_Plate.png
#
# [BATCH 35/40] /home/Data_Drive_8TB_2/Controllability/single-cell-grn-control/data/inferred_grn/phase4/Primordial_Germ_cells.ncol
# [INFO] Loading: /home/Data_Drive_8TB_2/Controllability/single-cell-grn-control/data/inferred_grn/phase4/Primordial_Germ_cells.ncol
# [INFO] Using largest weak component: 320/324 nodes
# [INFO] Random AUC   : 0.750927
# [INFO] Targeted AUC : 0.118234
# [OK] Saved figure: ../../data/result/robustness/figure/phase4/Primordial_Germ_cells.png
#
# [BATCH 36/40] /home/Data_Drive_8TB_2/Controllability/single-cell-grn-control/data/inferred_grn/phase4/Somites.ncol
# [INFO] Loading: /home/Data_Drive_8TB_2/Controllability/single-cell-grn-control/data/inferred_grn/phase4/Somites.ncol
# [INFO] Random AUC   : 0.702980
# [INFO] Targeted AUC : 0.092422
# [OK] Saved figure: ../../data/result/robustness/figure/phase4/Somites.png
#
# [BATCH 37/40] /home/Data_Drive_8TB_2/Controllability/single-cell-grn-control/data/inferred_grn/phase4/Spinal_Cord.ncol
# [INFO] Loading: /home/Data_Drive_8TB_2/Controllability/single-cell-grn-control/data/inferred_grn/phase4/Spinal_Cord.ncol
# [INFO] Random AUC   : 0.626139
# [INFO] Targeted AUC : 0.049270
# [OK] Saved figure: ../../data/result/robustness/figure/phase4/Spinal_Cord.png
#
# [BATCH 38/40] /home/Data_Drive_8TB_2/Controllability/single-cell-grn-control/data/inferred_grn/phase4/Tailbud.ncol
# [INFO] Loading: /home/Data_Drive_8TB_2/Controllability/single-cell-grn-control/data/inferred_grn/phase4/Tailbud.ncol
# [INFO] Random AUC   : 0.615977
# [INFO] Targeted AUC : 0.033533
# [OK] Saved figure: ../../data/result/robustness/figure/phase4/Tailbud.png
#
# [BATCH 39/40] /home/Data_Drive_8TB_2/Controllability/single-cell-grn-control/data/inferred_grn/phase4/Telencephalon.ncol
# [INFO] Loading: /home/Data_Drive_8TB_2/Controllability/single-cell-grn-control/data/inferred_grn/phase4/Telencephalon.ncol
# [INFO] Random AUC   : 0.684955
# [INFO] Targeted AUC : 0.098620
# [OK] Saved figure: ../../data/result/robustness/figure/phase4/Telencephalon.png
#
# [BATCH 40/40] /home/Data_Drive_8TB_2/Controllability/single-cell-grn-control/data/inferred_grn/phase4/midbrain+neural_crest.ncol
# [INFO] Loading: /home/Data_Drive_8TB_2/Controllability/single-cell-grn-control/data/inferred_grn/phase4/midbrain+neural_crest.ncol
# [INFO] Random AUC   : 0.607285
# [INFO] Targeted AUC : 0.057034
# [OK] Saved figure: ../../data/result/robustness/figure/phase4/midbrain+neural_crest.png
# [OK] Saved summary table: ../../data/result/robustness/robustness_summary.csv

# %%
Robustness_results
# Out:
#      phase                         network  random_auc  targeted_auc
# 0   phase1                     Blastomeres    0.589191      0.032857
# 1   phase1                Enveloping_Layer    0.744938      0.062697
# 2   phase1           Primordial_Germ_cells    0.747251      0.091122
# 3   phase2                        Ectoderm    0.632711      0.036512
# 4   phase2                Enveloping_Layer    0.665720      0.041767
# 5   phase2            Other_Axial_Mesoderm    0.652983      0.036349
# 6   phase2               Other_Mesendoderm    0.615644      0.028812
# 7   phase2           Primordial_Germ_cells    0.629895      0.044960
# 8   phase3                        Ectoderm    0.633301      0.037008
# 9   phase3                Enveloping_Layer    0.605942      0.031439
# 10  phase3                       Notochord    0.606263      0.031548
# 11  phase3               Other_Mesendoderm    0.641630      0.024084
# 12  phase3               Paraxial_Mesoderm    0.592667      0.024743
# 13  phase3                Prechordal_Plate    0.513162      0.025804
# 14  phase3           Primordial_Germ_cells    0.671608      0.076499
# 15  phase4                   Adaxial_Cells    0.621350      0.031813
# 16  phase4               Cephalic_Mesoderm    0.739528      0.136683
# 17  phase4                    Diencephalon    0.634132      0.044032
# 18  phase4  Endoderm_Pancreatic+Intestinal    0.667592      0.055440
# 19  phase4             Endoderm_Pharyngeal    0.708061      0.091964
# 20  phase4                Enveloping_Layer    0.741106      0.064966
# 21  phase4                       Epidermis    0.610070      0.037409
# 22  phase4                Heart_Primordium    0.698986      0.111525
# 23  phase4               Hematopoietic_ICM    0.681001      0.067575
# 24  phase4    Hematopoietic_RBI+Pronephros    0.697761      0.113896
# 25  phase4                    Hindbrain_R3    0.721452      0.117428
# 26  phase4                Hindbrain_R4+5+6    0.637969      0.052730
# 27  phase4             Neural_Plate_Border    0.670825      0.073093
# 28  phase4                       Notochord    0.703408      0.082776
# 29  phase4                       Optic_Cup    0.688320      0.061466
# 30  phase4   Placode_Adeno+Lens+Trigeminal    0.719162      0.110094
# 31  phase4       Placode_Epibranchial+Otic    0.660523      0.059167
# 32  phase4               Placode_Olfactory    0.708403      0.123403
# 33  phase4                Prechordal_Plate    0.543448      0.033921
# 34  phase4           Primordial_Germ_cells    0.750927      0.118234
# 35  phase4                         Somites    0.702980      0.092422
# 36  phase4                     Spinal_Cord    0.626139      0.049270
# 37  phase4                         Tailbud    0.615977      0.033533
# 38  phase4                   Telencephalon    0.684955      0.098620
# 39  phase4           midbrain+neural_crest    0.607285      0.057034
