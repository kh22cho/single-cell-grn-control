# %% [markdown]
# ___
# # edge category extraction
# ___
#
# ## procedure
# - run `netctrl` and save GML format file for each networks
# - parsing the GML(Graph Modeling Language) file and save edge category information into JSON file format
# - extract critical edge source gene information

# %%
# import modules
from pathlib import Path
import os, re, json, subprocess
import pandas as pd

# set path
DEFAULT_NETCTRL = '/home/Program/netctrl/build/src/ui/netctrl' # netctrl path
NOTEBOOK_DIR = Path.cwd() # current path
BASE_DIR = NOTEBOOK_DIR.parents[1] # working directory
INFERRED_DIR = BASE_DIR / 'data' / 'inferred_grn' # ncol file path
RESULT_DIR = BASE_DIR / 'data' / 'result' # result file saving path
GML_ROOT = RESULT_DIR / 'gml' # gml file path
RESULT_JSON = RESULT_DIR / 'edge_classes_liu.json'
RESULT_CRITICAL_TF = RESULT_DIR / 'critical_TF.csv'

RESULT_DIR.mkdir(parents=True, exist_ok=True)
GML_ROOT.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## function define
# - `run_netctrl_to_gml`: generate GML file from ncol
# - `parse_gml_edge_classes`: generate edge category JSON file from GML

# %%
# function that generate GML file
def run_netctrl_to_gml(ncol_path: Path, gml_path: Path, netctrl_paht: DEFAULT_NETCTRL):
    gml_path.parent.mkdir(parents=True, exist_ok=True)
    cmd = [str(DEFAULT_NETCTRL), '-m', 'liu', '-M', 'graph', '-F', 'gml', '-o', str(gml_path), str(ncol_path)]
    res = subprocess.run(cmd, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)
    if res.returncode != 0:
        raise RuntimeError(f'netctrl failed ({res.returncode}) for {ncol_path}\nSTDOUT:\n{res.stdout}\nSTDERR:\n{res.stderr}')

# compile regular expression pattern
NAME_RE = re.compile(r'^name\s+\"(.*)\"\s*$')
EDGECLASS_RE = re.compile(r'^edgeclass\s+\"(.*)\"\s*$')

# function that generate JSON file
def parse_gml_edge_classes(gml_path: Path):
    id_to_name = {}
    categories = { 'critical': [], 'ordinary': [], 'redundant': [] }

    in_node = False
    in_edge = False
    node_id = None
    node_name = None
    src = None
    tgt = None
    cls = None

    def commit_node():
        if node_id is not None:
            id_to_name[str(node_id)] = node_name if node_name is not None else str(node_id)

    def commit_edge():
        if src is None or tgt is None:
            return
        edge_class = (cls or '').lower()
        if edge_class not in categories:
            return
        s = id_to_name.get(str(src), str(src))
        t = id_to_name.get(str(tgt), str(tgt))
        categories[edge_class].append([s, t])

    with open(gml_path, 'r', encoding='utf-8') as f:
        for raw in f:
            line = raw.strip()
            if not line:
                continue

            # block start poing
            if line.startswith('node') and not in_node and not in_edge:
                in_node = True
                node_id = None
                node_name = None
                continue
            if line.startswith('edge') and not in_edge and not in_node:
                in_edge = True
                src = None
                tgt = None
                cls = None
                continue

            # block end point
            if line == ']':
                if in_node:
                    commit_node()
                    in_node = False
                    node_id = None
                    node_name = None
                    continue
                if in_edge:
                    commit_edge()
                    in_edge = False
                    src = None
                    tgt = None
                    cls = None
                    continue

            # inside of node block
            if in_node:
                if line.startswith('id '):
                    try:
                        node_id = int(line.split()[1])
                    except Exception:
                        pass
                    continue
                m = NAME_RE.match(line)
                if m:
                    node_name = m.group(1)
                    continue

            # inside of edge block
            if in_edge:
                if line.startswith('source '):
                    try:
                        src = int(line.split()[1])
                    except Exception:
                        pass
                    continue
                if line.startswith('target '):
                    try:
                        tgt = int(line.split()[1])
                    except Exception:
                        pass
                    continue
                m = EDGECLASS_RE.match(line)
                if m:
                    cls = m.group(1)
                    continue

    return categories

# %% [markdown]
# ## select specific phase or network (optional)
# - if `PHASE_FILTER` is None, then select all phase equal to `phase*`
# - if set `NETWORK_LIMIT`, then select top N networks

# %%
PHASE_FILTER = []  # ex: ['phase4'] or [] all phase
NETWORK_LIMIT = None  # ex: numeric value or None

# %% [markdown]
# ## run and generate GML

# %%
# result dictionary
result = {}

# phase directory for loop 
phase_dirs = sorted([p for p in INFERRED_DIR.iterdir() if p.is_dir() and p.name.startswith('phase')])
for phase_dir in phase_dirs:
    phase = phase_dir.name
    if PHASE_FILTER and phase not in PHASE_FILTER:
        continue
    result.setdefault(phase, {})

    # ncol network file for loop
    ncols = sorted(phase_dir.glob('*.ncol'))
    if NETWORK_LIMIT is not None:
        ncols = ncols[:NETWORK_LIMIT]

    for ncol_path in ncols:
        network_name = ncol_path.stem
        gml_dir = GML_ROOT / phase
        gml_path = gml_dir / f'{network_name}.gml'

        # 1) generate GML
        run_netctrl_to_gml(ncol_path, gml_path, DEFAULT_NETCTRL)

        # 2) parsing GML
        categories = parse_gml_edge_classes(gml_path)
        result[phase][network_name] = categories

        c = categories
        print(f"{phase}/{network_name}: critical={len(c['critical'])}, ordinary={len(c['ordinary'])}, redundant={len(c['redundant'])}")
# Out:
# phase1/Blastomeres: critical=11, ordinary=861, redundant=398
# phase1/Enveloping_Layer: critical=1, ordinary=2651, redundant=59
# phase1/Primordial_Germ_cells: critical=5, ordinary=920, redundant=29
# phase2/Ectoderm: critical=9, ordinary=769, redundant=352
# phase2/Enveloping_Layer: critical=26, ordinary=1094, redundant=623
# phase2/Other_Axial_Mesoderm: critical=10, ordinary=796, redundant=451
# phase2/Other_Mesendoderm: critical=12, ordinary=651, redundant=180
# phase2/Primordial_Germ_cells: critical=13, ordinary=488, redundant=140
# phase3/Ectoderm: critical=12, ordinary=960, redundant=266
# phase3/Enveloping_Layer: critical=16, ordinary=836, redundant=304
# phase3/Notochord: critical=14, ordinary=551, redundant=184
# phase3/Other_Mesendoderm: critical=16, ordinary=712, redundant=281
# phase3/Paraxial_Mesoderm: critical=12, ordinary=682, redundant=120
# phase3/Prechordal_Plate: critical=5, ordinary=546, redundant=106
# phase3/Primordial_Germ_cells: critical=14, ordinary=911, redundant=283
# phase4/Adaxial_Cells: critical=10, ordinary=411, redundant=77
# phase4/Cephalic_Mesoderm: critical=8, ordinary=1551, redundant=469
# phase4/Diencephalon: critical=20, ordinary=452, redundant=167
# phase4/Endoderm_Pancreatic+Intestinal: critical=38, ordinary=513, redundant=458
# phase4/Endoderm_Pharyngeal: critical=38, ordinary=634, redundant=1022
# phase4/Enveloping_Layer: critical=6, ordinary=2195, redundant=101
# phase4/Epidermis: critical=9, ordinary=562, redundant=186
# phase4/Heart_Primordium: critical=3, ordinary=1460, redundant=307
# phase4/Hematopoietic_ICM: critical=21, ordinary=385, redundant=278
# phase4/Hematopoietic_RBI+Pronephros: critical=25, ordinary=630, redundant=577
# phase4/Hindbrain_R3: critical=5, ordinary=933, redundant=120
# phase4/Hindbrain_R4+5+6: critical=19, ordinary=456, redundant=251
# phase4/Neural_Plate_Border: critical=6, ordinary=659, redundant=427
# phase4/Notochord: critical=4, ordinary=1180, redundant=243
# phase4/Optic_Cup: critical=12, ordinary=520, redundant=261
# phase4/Placode_Adeno+Lens+Trigeminal: critical=17, ordinary=738, redundant=779
# phase4/Placode_Epibranchial+Otic: critical=20, ordinary=496, redundant=373
# phase4/Placode_Olfactory: critical=18, ordinary=885, redundant=529
# phase4/Prechordal_Plate: critical=10, ordinary=409, redundant=46
# phase4/Primordial_Germ_cells: critical=13, ordinary=1282, redundant=107
# phase4/Somites: critical=10, ordinary=985, redundant=785
# phase4/Spinal_Cord: critical=32, ordinary=405, redundant=262
# phase4/Tailbud: critical=12, ordinary=421, redundant=95
# phase4/Telencephalon: critical=6, ordinary=911, redundant=174
# phase4/midbrain+neural_crest: critical=16, ordinary=383, redundant=155

# %% [markdown]
# ## save result into JSON

# %%
# save into JSON
with open(RESULT_JSON, 'w', encoding='utf-8') as f:
    json.dump(result, f, ensure_ascii=False, indent=2)

# %%
# critical TF visualization by dataframe format
with open(RESULT_JSON, 'r', encoding='utf-8') as f:
    data = json.load(f)

rows = []
for phase, nets in data.items():
    for network, categories in nets.items():
        critical_edges = categories.get('critical', [])
        sources = [pair[0] for pair in critical_edges]  # critical TF
        sources_str = ",".join(map(str, sources)) if sources else ""
        rows.append({
            "phase": phase,
            "network": network,
            "critical_TF": sources_str
        })

df = pd.DataFrame(rows).sort_values(["phase", "network"]).reset_index(drop=True)
df
# Out:
#      phase                         network  \
# 0   phase1                     Blastomeres
# 1   phase1                Enveloping_Layer
# 2   phase1           Primordial_Germ_cells
# 3   phase2                        Ectoderm
# 4   phase2                Enveloping_Layer
# 5   phase2            Other_Axial_Mesoderm
# 6   phase2               Other_Mesendoderm
# 7   phase2           Primordial_Germ_cells
# 8   phase3                        Ectoderm
# 9   phase3                Enveloping_Layer
# 10  phase3                       Notochord
# 11  phase3               Other_Mesendoderm
# 12  phase3               Paraxial_Mesoderm
# 13  phase3                Prechordal_Plate
# 14  phase3           Primordial_Germ_cells
# 15  phase4                   Adaxial_Cells
# 16  phase4               Cephalic_Mesoderm
# 17  phase4                    Diencephalon
# 18  phase4  Endoderm_Pancreatic+Intestinal
# 19  phase4             Endoderm_Pharyngeal
# 20  phase4                Enveloping_Layer
# 21  phase4                       Epidermis
# 22  phase4                Heart_Primordium
# 23  phase4               Hematopoietic_ICM
# 24  phase4    Hematopoietic_RBI+Pronephros
# 25  phase4                    Hindbrain_R3
# 26  phase4                Hindbrain_R4+5+6
# 27  phase4             Neural_Plate_Border
# 28  phase4                       Notochord
# 29  phase4                       Optic_Cup
# 30  phase4   Placode_Adeno+Lens+Trigeminal
# 31  phase4       Placode_Epibranchial+Otic
# 32  phase4               Placode_Olfactory
# 33  phase4                Prechordal_Plate
# 34  phase4           Primordial_Germ_cells
# 35  phase4                         Somites
# 36  phase4                     Spinal_Cord
# 37  phase4                         Tailbud
# 38  phase4                   Telencephalon
# 39  phase4           midbrain+neural_crest
#
#                                           critical_TF
# 0   FOXB1A,FOXD3,FOXD5,HOPX,KLF6A,POU5F3,SI:DKEY-2...
# 1                                               FOXD3
# 2                         FOXB1A,ID3,RARGA,VED,ZNF503
# 3      BLF,EVE1,HER7,ID1,MSX1B,OTX1B,TFAP2C,VOX,ZEB1A
# 4   BLF,CABZ01070258.1,CEBPD,CTH1,ETV4,FOXA,FOXD3,...
# 5   CABZ01070258.1,DRL,HER7,HMGB1A,HOPX,MYT1A,NOTO...
# 6   CDX4,E2F7,EVE1,FOSAB,FOXA2,HER5,MSGN1,OSR1,OTX...
# 7   CDX4,HER3,HER5,HER7,ID2A,ID3,IRX7,MYCN,OTX1B,T...
# 8   DLX3B,GATA3,HER5,HMGB1A,IRX1B,OLIG3,OTX2,PAX2A...
# 9   ATF3,FOXB1A,GBX1,ID1,ID3,MEIS2B,OTX1A,RARGA,SI...
# 10  CTH1,FOXA1,FOXA2,GBX1,IRX5A,KLF6A,MIXL1,NOTO,O...
# 11  CABZ01070258.1,DMBX1A,FEZF2,FOXA2,GSC,MEIS3,MY...
# 12  FOSAB,FOXA,FOXB1A,FOXD3,NEUROG1,NOTO,PRDM1A,SA...
# 13           BACH1B,ETV4,PITX2,SI:DKEY-68O6.5,UNCX4.1
# 14  DLX3B,ETS2,EVE1,FOXC1A,FOXD3,HER5,HOXB7A,IRX1B...
# 15  BLF,HER1,HOXA9B,HOXB10A,JUN,SI:DKEY-261J4.5,SI...
# 16         HEY2,LMX1BB,MSGN1,MSX3,PBX1A,SOX13,VED,VOX
# 17  ARXA,DBX1A,DBX1B,EMX3,ENG2B,INSM1B,IRX1B,IRX7,...
# 18  ATF3,BLF,CABZ01070258.1,DLX3B,ETV4,FOXA,FOXA3,...
# 19  FOXA3,GATA6,GBX1,GSC,HER5,HER6,HER9,HOXB3A,HOX...
# 20               GRHL2B,HOXB1B,HOXB9A,SIX7,SOX3,TBX16
# 21  ATF3,CDX4,FOXI3A,MSX3,MYCN,RARGA,TCF3B,TP63,ZB...
# 22                                   ETV2,IRX3A,PAX2A
# 23  CEBPA,ETV4,GATA2A,GBX2,GFI1AA,GSC,HER15.1,HER1...
# 24  CABZ01070258.1,ETV4,FLI1A,FOXC1A,FOXJ1A,HOXB1A...
# 25                          KLF6A,RX3,VOX,ZEB1A,ZFP36
# 26  ATF3,CDX4,DBX1A,DBX2,ETV4,HER13,HER15.2,HER6,H...
# 27                  DLX5A,EVE1,HER9,MEIS1B,MSX1B,SOX3
# 28                            MEF2D,SOX2,TBX16,ZNFL2A
# 29  CDX4,E2F7,FOXD1,FOXG1A,NR2F2,OTX1A,SIX7,SOX11A...
# 30  DMBX1A,FOXD3,GBX2,GSC,HER15.2,HER5,HEY1,HOPX,K...
# 31  CABZ01070258.1,DLX4B,FOSAB,HER2,HOXA3A,JUN,LMX...
# 32  E2F7,FOXB1A,FOXG1A,HER3,HOXB1A,HOXC8A,HOXD4A,I...
# 33  DMBX1A,ID2A,MYCN,OTX1A,SOX11A,SOX9B,TCF3B,UBTF...
# 34  CDX4,FOXG1A,HER4.1,HOPX,HOXB1B,HOXC1A,IRX7,MYF...
# 35  HER15.1,HOXB7A,HOXC10A,ID2A,JDP2B,MYF5,SNAI1A,...
# 36  BHLHE22,CDX4,ENG2B,ETV4,FOXB1A,HER13,HER15.1,H...
# 37  CDX4,HOXA9B,HOXC8A,ID1,MSX1B,MYCN,NEUROG1,NKX1...
# 38                   CDX4,E2F7,HOXC3A,MYT1B,PAX3A,VED
# 39  DMBX1A,EGR2B,ETV4,FOXD3,HES6,ID3,IRX5A,JUNBA,M...

# %%
# save critical TF
df.to_csv(RESULT_CRITICAL_TF)
