# %% [markdown]
# ___
# ### make edge categorized dictionary from `netctrl_results_liu.json`
# ___

# %%
# import module

import json
import os
import csv
import pandas as pd

# %%
# read JSON file
json_file_path = "../../data/result/netctrl_results_liu.json"

with open(json_file_path, 'r', encoding='utf-8') as json_file:
    netctrl_results = json.load(json_file)

# read all network files for edge information
file_name = {f'phase{i}': os.listdir('../../data/inferred_grn' + f"/phase{i}/") for i in range(1, 5)}

# read nD criteria csv file
criteria = pd.read_csv("../../data/result/netctrl_criteria_liu.csv", sep = ',')
criteria.head()
# Out:
#     phase                network   nD
# 0  phase1  Primordial_Germ_cells  214
# 1  phase1            Blastomeres  451
# 2  phase1       Enveloping_Layer  434
# 3  phase2               Ectoderm  394
# 4  phase2  Primordial_Germ_cells  293

# %%
# result dictionary
results_dict = {}

# phase for loop 
for phase, networks in netctrl_results.items():
    results_dict[phase] = {}

    for net_name, edge_results in networks.items():
        net_key = net_name.replace('.ncol', '')
        
        # nD criteria value
        criteria_value = criteria.loc[(criteria['phase'] == phase) & (criteria['network'] == net_key), 'nD']
        
        if criteria_value.empty:
            continue 
        
        criteria_value = criteria_value.item()
        
        # nD tendency with edge removal
        results_dict[phase][net_name] = {"decrease": [], "remain": [], "increase": []}
        
        # read network edge file
        edge_file_path = os.path.join('../../data/inferred_grn', phase, f'{net_name}.ncol')
        if not os.path.exists(edge_file_path):
            continue  
        
        # load edge information
        with open(edge_file_path, 'r') as edge_file:
            edges = edge_file.readlines()
        
        # edge comparison 
        for idx, (edge, value) in enumerate(zip(edges, edge_results.values()), start=1):
            value = int(value) 
            
            if value < criteria_value:
                results_dict[phase][net_name]["decrease"].append([idx, edge.strip(), value])
            elif value > criteria_value:
                results_dict[phase][net_name]["increase"].append([idx, edge.strip(), value])
            else:
                results_dict[phase][net_name]["remain"].append([idx, edge.strip(), value])

# save into JSON
output_json_path = "../../data/result/netctrl_results_liu_filtered.json" 

with open(output_json_path, 'w', encoding='utf-8') as out_file:
    json.dump(results_dict, out_file, indent=4, ensure_ascii=False)

# %%
# this is a example of critical edges
for phase in list(results_dict.keys()):
    print("==============================")
    print("===========", phase, "===========")
    print("==============================")
    for network in list(results_dict[phase].keys()):
        print("----------", network)
        for lc in results_dict[phase][network]['increase']:
            print(lc[1].split(' ')[0], '>>>', lc[1].split(' ')[1])
# Out:
# ==============================
# =========== phase1 ===========
# ==============================
# ---------- Primordial_Germ_cells
# ---------- Blastomeres
# FOXB1A >>> GOLGB1
# FOXD3 >>> ZGC:153675
# FOXD5 >>> LRWD1
# HOPX >>> ELL2
# KLF6A >>> ITSN2B
# POU5F3 >>> VGLL4L
# SI:DKEY-43P13.5 >>> RBM38
# SOX11A >>> EFHD1
# SOX13 >>> HER5
# ZEB1A >>> GOLGA4
# ---------- Enveloping_Layer
# ==============================
# =========== phase2 ===========
# ==============================
# ---------- Ectoderm
# BLF >>> NNR
# EVE1 >>> RGCC
# HER7 >>> SI:DKEY-27I16.2
# ID1 >>> FOXI1
# MSX1B >>> SEPH
# OTX1B >>> NOVA2
# TFAP2C >>> ZGC:153409
# VOX >>> DDX17
# ZEB1A >>> ASPM
# ---------- Primordial_Germ_cells
# HER5 >>> CHMP2BB
# HER7 >>> SEC61G
# ID2A >>> SALL4
# ID3 >>> TP53
# IRX7 >>> NPM2B
# MYCN >>> KIAA0101
# OTX1B >>> SSR4
# TA >>> SI:CH211-173M16.2
# XBP1 >>> P4HB
# ZEB1A >>> TPM3
# ZGC:113886 >>> GAPDH
# ---------- Other_Mesendoderm
# E2F7 >>> GOLGB1
# EVE1 >>> BLF
# FOXA2 >>> SEPW1
# HER5 >>> BTG2
# MSGN1 >>> EFNB2A
# SI:DKEY-261J4.3 >>> LRRC59
# SOX32 >>> COQ10B
# ---------- Other_Axial_Mesoderm
# CABZ01070258.1 >>> CAPNS1A
# DRL >>> CYP2AA8
# HMGB1A >>> SEPH
# HOPX >>> FOPNL
# MYT1A >>> TOP2A
# NOTO >>> PFN1
# SI:DKEY-261J4.3 >>> ZIC2A
# TWIST2 >>> TUBA8L2
# ---------- Enveloping_Layer
# CABZ01070258.1 >>> DYNLL2A
# CTH1 >>> UBE2C
# ETV4 >>> MAD2L1
# FOXA >>> MIBP
# FOXD3 >>> SI:DKEY-228B2.6
# FOXD5 >>> ARL4D
# FOXI1 >>> NPM2B
# HER7 >>> LRRC59
# ID1 >>> ZGC:92818
# ID3 >>> PRKRIP1
# IRX7 >>> P4HB
# SI:CH73-299H12.3 >>> ABRACL
# SI:DKEY-261J4.5 >>> SSR4
# SOX11B >>> DNTTIP2
# SOX2 >>> SI:CH73-52F24.4
# TA >>> UBTF
# TBX16 >>> ETV4
# TCF3B >>> ACP5A
# ZIC2B >>> DDIT4
# ZIC3 >>> PPRC1
# ZNFL2A >>> GAPDH
# ==============================
# =========== phase3 ===========
# ==============================
# ---------- Notochord
# CTH1 >>> SI:CH73-52F24.4
# FOXA1 >>> ZGC:153675
# GBX1 >>> CFL1
# KLF6A >>> CDH2
# OTX1A >>> DACT2
# POU5F3 >>> CHD
# RXRAA >>> FZD7A
# VOX >>> BTG2
# XBP1 >>> SI:DKEY-151G10.6
# ---------- Paraxial_Mesoderm
# FOXA >>> HDLBPA
# FOXB1A >>> LRWD1
# FOXD3 >>> SALL4
# NEUROG1 >>> SEPH
# NOTO >>> TP53
# PRDM1A >>> ZFAND5A
# SALL4 >>> HER6
# VED >>> SP5L
# VOX >>> SRP19
# XBP1 >>> ETV4
# ---------- Ectoderm
# DLX3B >>> TP53INP2
# GATA3 >>> SSR4
# HER5 >>> CCDC9
# OLIG3 >>> DNTTIP2
# OTX2 >>> HER5
# PAX2A >>> IRX1B
# TBX16 >>> ADD3B
# ZIC2A >>> SIX7
# ZIC3 >>> ZIC2A
# ---------- Primordial_Germ_cells
# EVE1 >>> SOX19A
# FOXD3 >>> QKIA
# IRX1B >>> TUBA8L4
# MEIS2B >>> MAD2L1
# PAX8 >>> UBE2C
# PRDM14 >>> NAP1L1
# TFAP2A >>> FBXO5
# ZNF503 >>> RRP1
# ---------- Other_Mesendoderm
# DMBX1A >>> PKDCCB
# FEZF2 >>> CYP26A1
# GSC >>> BTG2
# MEIS3 >>> TUBA1A
# MYF5 >>> PLK1
# NR2F6B >>> HDLBPA
# PITX2 >>> CENPF
# PRDM1A >>> YWHAZ
# TBX1 >>> FBXO5
# TFAP2A >>> PRDM1A
# TP63 >>> ZGC:92242
# ---------- Prechordal_Plate
# BACH1B >>> BIRC5A
# ETV4 >>> YWHAZ
# SI:DKEY-68O6.5 >>> FAM84A
# UNCX4.1 >>> CFL1
# ---------- Enveloping_Layer
# FOXB1A >>> HIST2H2AB
# GBX1 >>> SEPH
# ID1 >>> CDKN1CA
# ID3 >>> KCTD15A
# MEIS2B >>> HELLS
# OTX1A >>> PPRC1
# RARGA >>> FZD7A
# SI:DKEY-228B2.6 >>> ACIN1A
# SOX19A >>> UBE2C
# VED >>> PRKRIP1
# ZIC2A >>> TDGF1
# ZIC3 >>> RRP1
# ZNF503 >>> CITED4B
# ZNF750 >>> TTC31
# ==============================
# =========== phase4 ===========
# ==============================
# ---------- Notochord
# SOX2 >>> NDUFA4L
# ZNFL2A >>> SALL4
# ---------- Cephalic_Mesoderm
# MSX3 >>> PNN
# PBX1A >>> SSR3
# ---------- Diencephalon
# ARXA >>> ACTB1
# DBX1A >>> YWHAZ
# DBX1B >>> DLX3B
# EMX3 >>> HER9
# ENG2B >>> SEC61B
# INSM1B >>> TDH
# IRX1B >>> NR2E1
# MSX1B >>> PAX6A
# MYT1B >>> NAP1L1
# NOTO >>> ALDOB
# OLIG2 >>> SP5A
# PAX3A >>> NDUFA4L
# SOX1B >>> LHX2B
# VOX >>> SHISA2
# ZEB1A >>> SI:DKEY-56M19.5
# ZIC3 >>> SOX11A
# ---------- Neural_Plate_Border
# DLX5A >>> TP63
# MEIS1B >>> HOXC3A
# MSX1B >>> TPX2
# SOX3 >>> HOXB7A
# ---------- Placode_Epibranchial+Otic
# CABZ01070258.1 >>> EEF2B
# DLX4B >>> GLULB
# FOSAB >>> CXCR4A
# HOXA3A >>> SEPW1
# JUN >>> TUBA8L4
# NR2F5 >>> MARCKSL1B
# PRDM1A >>> ATP1B1A
# SIX1B >>> TTC31
# SOX10 >>> H1F0
# SOX2 >>> ZGC:92066
# SOX21A >>> SI:CH211-152C2.3
# TBX2B >>> SIX4A
# TCF3B >>> TPX2
# UBTF >>> APOC1
# ZNF503 >>> ABRACL
# ZNFL2A >>> YWHAQA
# ---------- Placode_Olfactory
# E2F7 >>> HIRIP3
# FOXB1A >>> PCNA
# FOXG1A >>> CABZ01070258.1
# HER3 >>> MKI67
# HOXB1A >>> APOEB
# HOXC8A >>> STMN1A
# HOXD4A >>> MIBP
# ISL1 >>> SSR3
# ISL2B >>> CDKN1CA
# KLF6A >>> NAP1L1
# MSX3 >>> CCNG1
# NHLH2 >>> SIX1B
# SIX3A >>> HSPB1
# ZNF503 >>> MYL12.1
# ---------- Hindbrain_R4+5+6
# ATF3 >>> APOEB
# DBX1A >>> IRX1B
# DBX2 >>> KPNA2
# ETV4 >>> NUSAP1
# HER13 >>> RPS12
# HER15.2 >>> CCND1
# HOXB1B >>> ATP1B1A
# HOXB3A >>> PPIG
# IRX7 >>> GAS1B
# MEIS3 >>> ZGC:92066
# MSX3 >>> MARCKSL1A
# NR2F2 >>> SI:CH211-113A14.18
# OLIG3 >>> SEC61B
# UBTF >>> CDX4
# ---------- Primordial_Germ_cells
# FOXG1A >>> JUNBA
# HOXB1B >>> SI:CH211-106E7.2
# HOXC1A >>> SEC61G
# IRX7 >>> FOXD3
# SOX21A >>> PLK1
# TWIST1B >>> RRM2
# ---------- Adaxial_Cells
# BLF >>> VED
# JUN >>> CFL1
# ---------- Hindbrain_R3
# VOX >>> BCAS2
# ---------- midbrain+neural_crest
# DMBX1A >>> HIRIP3
# EGR2B >>> MALAT1
# ETV4 >>> PTGDSB
# FOXD3 >>> ZC3H13
# HES6 >>> MARCKSL1A
# IRX5A >>> INCENP
# JUNBA >>> BTG2
# MAFBA >>> ANP32E
# MEIS3 >>> HSPB1
# OTX2 >>> SOX3
# SOX10 >>> ASPH
# SOX11A >>> DBX2
# SOX9B >>> ID1
# ZEB1A >>> MYCN
# ---------- Optic_Cup
# CDX4 >>> MEIS1B
# E2F7 >>> RPLP1
# FOXD1 >>> BAZ1B
# FOXG1A >>> HSPB1
# OTX1A >>> EEF2B
# SIX7 >>> PPRC1
# SOX13 >>> RPL38
# SOX1B >>> SI:CH73-1A9.3
# TBX2B >>> ID1
# ZBTB16A >>> RPL6
# ---------- Tailbud
# HOXC8A >>> DYNLL1
# MSX1B >>> ADAM8A
# MYCN >>> NASP
# NEUROG1 >>> AKAP12B
# NKX1.2LA >>> SI:CH211-152C2.3
# TFAP2A >>> MCM6
# ZIC2B >>> ETV4
# ---------- Placode_Adeno+Lens+Trigeminal
# DMBX1A >>> ZGC:92066
# FOXD3 >>> ACTB2
# GBX2 >>> HER9
# GSC >>> HISTH1L
# KLF2A >>> CX43.4
# MSX3 >>> BCAS2
# NR2F6B >>> NASP
# PAX6A >>> RPLP1
# PRDM1A >>> TP63
# SOX11B >>> SI:CH73-281N10.2
# TBX16 >>> XBP1
# TEAD1B >>> YWHAQA
# ZIC3 >>> DYNLL1
# ---------- Telencephalon
# ---------- Hematopoietic_ICM
# CEBPA >>> NRARPA
# ETV4 >>> CIRBPB
# GATA2A >>> PTMAA
# GBX2 >>> RRP1
# GFI1AA >>> TDH
# GSC >>> ACTB1
# HER15.1 >>> HDLBPA
# HER15.2 >>> FOSAB
# HER9 >>> MCM6
# HOXB3A >>> SEPH
# HOXD9A >>> PAX8
# KLF6A >>> PLK3
# MYCN >>> KIAA0101
# PAX8 >>> AKAP12B
# SI:DKEY-261J4.3 >>> CFL1
# SOX11B >>> NDUFA4L
# UBTF >>> KIF11
# XBP1 >>> CX43.4
# ---------- Prechordal_Plate
# DMBX1A >>> KRT4
# OTX1A >>> ATPV0E2
# ZBTB16A >>> PCNA
# ---------- Spinal_Cord
# BHLHE22 >>> MCM6
# CDX4 >>> MEIS3
# ENG2B >>> NAP1L1
# ETV4 >>> ACTB1
# FOXB1A >>> HER13
# HER15.1 >>> RPS28
# HER3 >>> CASP8AP2
# HOXA3A >>> SI:CH73-281N10.2
# IRX3A >>> SOX3
# JUN >>> MDKA
# MEIS1B >>> SI:CH211-193L2.4
# MYT1B >>> PNN
# NHLH2 >>> TMSB4X
# NR2F6B >>> SSR2
# POU3F1 >>> SI:CH211-193L2.5
# SCRT2 >>> SOX11A
# SOX13 >>> SI:CH73-1A9.3
# SOX3 >>> STMN1A
# UBTF >>> HSPA5
# XBP1 >>> SEPH
# ZNF503 >>> HELLS
# ---------- Epidermis
# ATF3 >>> SDC4
# CDX4 >>> PITX3
# MYCN >>> PDLIM1
# RARGA >>> RPL38
# TCF3B >>> ANP32E
# ZBTB16A >>> CDH1
# ---------- Hematopoietic_RBI+Pronephros
# CABZ01070258.1 >>> BCAS2
# ETV4 >>> SRSF10B
# FOXC1A >>> SEC61B
# FOXJ1A >>> SEC61G
# JUN >>> RPS25
# LHX1A >>> CALM3A
# MEIS1B >>> SFRP1A
# MEIS3 >>> TPX2
# MSX3 >>> SI:CH211-152C2.3
# NR2F6B >>> SOX21A
# OTX2 >>> BIRC5A
# PAX6A >>> KPNA2
# RARGA >>> GADD45BA
# SMAD3A >>> RPL6
# TFAP2A >>> DYNLL1
# XBP1 >>> MYCN
# ZIC2B >>> ANP32E
# ZIC3 >>> EIF4EBP3L
# ZNF503 >>> RPL38
# ---------- Enveloping_Layer
# SOX3 >>> SEPH
# TBX16 >>> MOB2A
# ---------- Heart_Primordium
# PAX2A >>> PNRC2
# ---------- Endoderm_Pancreatic+Intestinal
# ATF3 >>> PLTP
# BLF >>> UBE2C
# CABZ01070258.1 >>> MSX1B
# DLX3B >>> RPL29
# ETV4 >>> CDKN1CA
# FOXA3 >>> SI:CH73-234B20.5
# FOXB1B >>> HOXB10A
# FOXD3 >>> CCND1
# GATA6 >>> TPM3
# GBX1 >>> SSR4
# GRHL2B >>> NDUFA4L
# HER12 >>> SI:CH211-199G17.2
# HER15.1 >>> ABRACL
# HER2 >>> ZC3H13
# HER3 >>> NOP56
# HER7 >>> SEPH
# HES6 >>> PNRC2
# HOXA3A >>> RPS12
# HOXD9A >>> MEIS1B
# ID2A >>> RPS18
# IRX1B >>> SOX11A
# JDP2B >>> H1F0
# MEIS1B >>> RPS20
# MEIS2B >>> MARCKSL1A
# MSX3 >>> STM
# NR2F5 >>> TPX2
# PAX3A >>> CDCA7A
# PAX6A >>> SSR2
# PAX6B >>> SOX11B
# SOX13 >>> SSR3
# SP5A >>> AKAP12B
# TCF15 >>> SI:CH211-222L21.1
# TEAD1B >>> SI:DKEY-151G10.6
# TFAP2A >>> TBX16
# ZNF503 >>> KRT18
# ---------- Endoderm_Pharyngeal
# FOXA3 >>> CNN3A
# GATA6 >>> SI:DKEY-261H17.1
# GBX1 >>> YWHAZ
# GSC >>> FOXA1
# HER5 >>> PCNA
# HER6 >>> TXN
# HER9 >>> SEPW1
# HOXB3A >>> RPS25
# HOXC3A >>> HSPB1
# HOXD4A >>> SI:CH211-222L21.1
# ID2A >>> IRX7
# IRX7 >>> SI:CH73-281N10.2
# ISL1 >>> KRT18
# JUNBA >>> UBE2C
# MEIS3 >>> CCND1
# MSGN1 >>> STM
# MSX3 >>> DENR
# MYF5 >>> SI:CH73-1A9.3
# NR2F2 >>> SSR4
# NR2F6B >>> F11R.1
# OTX1B >>> SEPH
# PITX2 >>> PLTP
# PRDM1A >>> ID1
# SNAI1A >>> MAD2L1
# SOX13 >>> SOX11B
# SOX2 >>> PNRC2
# SOX9B >>> RPS20
# TBX2B >>> YWHAQA
# TBX3A >>> FSCN1A
# TEAD1B >>> MYCN
# TFA >>> MCAMA
# TFAP2C >>> TFAP2A
# TP63 >>> TOP2A
# TWIST1B >>> ALCAMB
# ZNF503 >>> ZIC2B
# ---------- Somites
# HER15.1 >>> DNTTIP2
# HOXB7A >>> NID2A
# HOXC10A >>> HSPB1
# ID2A >>> KCTD5A
# JDP2B >>> GUSB
# SNAI1A >>> RPS28
# TBX6L >>> RPL29
# UBTF >>> CDX4
# UNCX4.1 >>> FOSAB

# %%
# calculate critical TF
rows = []

for phase in list(results_dict.keys()):
    for network in list(results_dict[phase].keys()):
        
        phase_net = f"{phase}_{network}"

        lc_genes = [
            lc[1].split(' ')[0]
            for lc in results_dict[phase][network].get('increase', [])
            if lc and len(lc) > 1
        ]

        if not lc_genes:
            continue

        rows.append([phase_net] + lc_genes)

df = pd.DataFrame(rows)

# save a result
df.to_csv('../../data/result/critical_TF.csv', header=False)
df.head()
# Out:
#                              0               1      2       3     4      5   \
# 0            phase1_Blastomeres          FOXB1A  FOXD3   FOXD5  HOPX  KLF6A
# 1               phase2_Ectoderm             BLF   EVE1    HER7   ID1  MSX1B
# 2  phase2_Primordial_Germ_cells            HER5   HER7    ID2A   ID3   IRX7
# 3      phase2_Other_Mesendoderm            E2F7   EVE1   FOXA2  HER5  MSGN1
# 4   phase2_Other_Axial_Mesoderm  CABZ01070258.1    DRL  HMGB1A  HOPX  MYT1A
#
#                 6                7       8      9   ...    26    27    28  \
# 0           POU5F3  SI:DKEY-43P13.5  SOX11A  SOX13  ...  None  None  None
# 1            OTX1B           TFAP2C     VOX  ZEB1A  ...  None  None  None
# 2             MYCN            OTX1B      TA   XBP1  ...  None  None  None
# 3  SI:DKEY-261J4.3            SOX32    None   None  ...  None  None  None
# 4             NOTO  SI:DKEY-261J4.3  TWIST2   None  ...  None  None  None
#
#      29    30    31    32    33    34    35
# 0  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None
#
# [5 rows x 36 columns]
