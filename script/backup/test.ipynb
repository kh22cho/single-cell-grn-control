# %%
import pandas as pd
from pathlib import Path

# 파일 경로 설정
# Type A: "0,phase1_Blastomeres,FOXB1A,FOXD3,..."
TYPE_A_CSV = Path('../../data/result/critical_TF.csv')          # 예시 경로
# Type B: ",phase,network,critical_TF" (콤마로 구분된 문자열)
TYPE_B_CSV = Path('./critical_TF.csv')                  # 예시 경로

assert TYPE_A_CSV.exists(), f"Not found: {TYPE_A_CSV}"
assert TYPE_B_CSV.exists(), f"Not found: {TYPE_B_CSV}"

def parse_type_a(csv_path: Path):
    # header 없음, 0열: index, 1열: "phaseX_network", 2열~: TF들
    df = pd.read_csv(csv_path, header=None, dtype=str).fillna('')
    data = {}
    for _, row in df.iterrows():
        key = str(row.iloc[1]).strip()
        if '_' in key:
            phase, network = key.split('_', 1)  # 첫 '_'만 분리
        else:
            # 비정형이면 phase 비움
            phase, network = '', key
        tfs = {str(x).strip() for x in row.iloc[2:].tolist() if str(x).strip()}
        data.setdefault(phase, {}).setdefault(network, set()).update(tfs)
    return data

def parse_type_b(csv_path: Path):
    # header 있음: phase, network, critical_TF (콤마로 연결된 문자열)
    df = pd.read_csv(csv_path, dtype=str).fillna('')
    data = {}
    for _, row in df.iterrows():
        phase = str(row['phase']).strip()
        network = str(row['network']).strip()
        tfs = str(row['critical_TF']).strip()
        if tfs.startswith('[') and tfs.endswith(']'):
            # 혹시 리스트 문자열로 저장된 경우
            tfs = tfs.strip('[]')
        tf_list = [s.strip().strip('"').strip("'") for s in tfs.split(',') if s.strip()]
        data.setdefault(phase, {}).setdefault(network, set()).update(tf_list)
    return data

a = parse_type_a(TYPE_A_CSV)  # 내 방식
b = parse_type_b(TYPE_B_CSV)  # netctrl에서 정리한 형식(or 너가 만든 형식)

# (phase, network) 전체 키 집합
keys = set()
for p in a:
    for n in a[p]:
        keys.add((p, n))
for p in b:
    for n in b[p]:
        keys.add((p, n))

rows = []
for phase, network in sorted(keys):
    my_set = a.get(phase, {}).get(network, set())
    our_set = b.get(phase, {}).get(network, set())
    rows.append({
        'phase': phase,
        'network': network,
        'my_count': len(my_set),
        'our_count': len(our_set),
        'intersection': len(my_set & our_set),
        'only_in_my': len(my_set - our_set),
        'only_in_our': len(our_set - my_set),
        'is_my_subset_of_our': my_set.issubset(our_set),
        'is_our_subset_of_my': our_set.issubset(my_set),
        # 상세 목록 보고 싶으면 아래 주석 해제
        # 'only_in_my_list': ','.join(sorted(my_set - our_set)),
        # 'only_in_our_list': ','.join(sorted(our_set - my_set)),
    })

cmp_df = pd.DataFrame(rows).sort_values(['phase','network']).reset_index(drop=True)
cmp_df
# Out:
#      phase                         network  my_count  our_count  intersection  \
# 0   phase1                     Blastomeres        10         11            10
# 1   phase1                Enveloping_Layer         0          1             0
# 2   phase1           Primordial_Germ_cells         0          5             0
# 3   phase2                        Ectoderm         9          9             9
# 4   phase2                Enveloping_Layer        21         26            21
# 5   phase2            Other_Axial_Mesoderm         8         10             8
# 6   phase2               Other_Mesendoderm         7         12             7
# 7   phase2           Primordial_Germ_cells        11         13            11
# 8   phase3                        Ectoderm         9         12             9
# 9   phase3                Enveloping_Layer        14         16            14
# 10  phase3                       Notochord         9         14             9
# 11  phase3               Other_Mesendoderm        11         16            11
# 12  phase3               Paraxial_Mesoderm        10         12            10
# 13  phase3                Prechordal_Plate         4          5             4
# 14  phase3           Primordial_Germ_cells         8         14             8
# 15  phase4                   Adaxial_Cells         2         10             2
# 16  phase4               Cephalic_Mesoderm         2          8             2
# 17  phase4                    Diencephalon        16         20            16
# 18  phase4  Endoderm_Pancreatic+Intestinal        35         38            35
# 19  phase4             Endoderm_Pharyngeal        35         38            35
# 20  phase4                Enveloping_Layer         2          6             2
# 21  phase4                       Epidermis         6          9             6
# 22  phase4                Heart_Primordium         1          3             1
# 23  phase4               Hematopoietic_ICM        18         21            18
# 24  phase4    Hematopoietic_RBI+Pronephros        19         25            19
# 25  phase4                    Hindbrain_R3         1          5             1
# 26  phase4                Hindbrain_R4+5+6        14         19            14
# 27  phase4             Neural_Plate_Border         4          6             4
# 28  phase4                       Notochord         2          4             2
# 29  phase4                       Optic_Cup        10         12            10
# 30  phase4   Placode_Adeno+Lens+Trigeminal        13         17            13
# 31  phase4       Placode_Epibranchial+Otic        16         20            16
# 32  phase4               Placode_Olfactory        14         18            14
# 33  phase4                Prechordal_Plate         3         10             3
# 34  phase4           Primordial_Germ_cells         6         13             6
# 35  phase4                         Somites         9         10             9
# 36  phase4                     Spinal_Cord        21         32            21
# 37  phase4                         Tailbud         7         12             7
# 38  phase4                   Telencephalon         0          6             0
# 39  phase4           midbrain+neural_crest        14         16            14
#
#     only_in_my  only_in_our  is_my_subset_of_our  is_our_subset_of_my
# 0            0            1                 True                False
# 1            0            1                 True                False
# 2            0            5                 True                False
# 3            0            0                 True                 True
# 4            0            5                 True                False
# 5            0            2                 True                False
# 6            0            5                 True                False
# 7            0            2                 True                False
# 8            0            3                 True                False
# 9            0            2                 True                False
# 10           0            5                 True                False
# 11           0            5                 True                False
# 12           0            2                 True                False
# 13           0            1                 True                False
# 14           0            6                 True                False
# 15           0            8                 True                False
# 16           0            6                 True                False
# 17           0            4                 True                False
# 18           0            3                 True                False
# 19           0            3                 True                False
# 20           0            4                 True                False
# 21           0            3                 True                False
# 22           0            2                 True                False
# 23           0            3                 True                False
# 24           0            6                 True                False
# 25           0            4                 True                False
# 26           0            5                 True                False
# 27           0            2                 True                False
# 28           0            2                 True                False
# 29           0            2                 True                False
# 30           0            4                 True                False
# 31           0            4                 True                False
# 32           0            4                 True                False
# 33           0            7                 True                False
# 34           0            7                 True                False
# 35           0            1                 True                False
# 36           0           11                 True                False
# 37           0            5                 True                False
# 38           0            6                 True                False
# 39           0            2                 True                False
